# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from core import *

# %%
df = pd.read_hdf('results/pe.hdf', 'white/red_noise/masked')

# %%
with sb.plotting_context('talk'):
    jg = sb.jointplot(df.b, df.k, stat_func=None, kind='kde', xlim=(0.81,0.88), ylim=(0.157,0.178), );
    jg.set_axis_labels('Impact parameter', 'Radius ratio')
    jg.fig.savefig('plots/EWASS_b_vs_k.png', dpi=200)
